# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns
import random
sns.set()

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2020-05-04  1308.229980  1327.660034  1299.000000  1326.800049
# 1  2020-05-05  1337.920044  1373.939941  1337.459961  1351.109985
# 2  2020-05-06  1361.689941  1371.119995  1347.290039  1347.300049
# 3  2020-05-07  1365.939941  1377.599976  1355.270020  1372.560059
# 4  2020-05-08  1383.130005  1398.760010  1375.479980  1388.369995
#
#      Adj Close   Volume
# 0  1326.800049  1504000
# 1  1351.109985  1651500
# 2  1347.300049  1215400
# 3  1372.560059  1397600
# 4  1388.369995  1386900

# %%
class Deep_Evolution_Strategy:

    inputs = None

    def __init__(
        self, weights, reward_function, population_size, sigma, learning_rate
    ):
        self.weights = weights
        self.reward_function = reward_function
        self.population_size = population_size
        self.sigma = sigma
        self.learning_rate = learning_rate

    def _get_weight_from_population(self, weights, population):
        weights_population = []
        for index, i in enumerate(population):
            jittered = self.sigma * i
            weights_population.append(weights[index] + jittered)
        return weights_population

    def get_weights(self):
        return self.weights

    def train(self, epoch = 100, print_every = 1):
        lasttime = time.time()
        for i in range(epoch):
            population = []
            rewards = np.zeros(self.population_size)
            for k in range(self.population_size):
                x = []
                for w in self.weights:
                    x.append(np.random.randn(*w.shape))
                population.append(x)
            for k in range(self.population_size):
                weights_population = self._get_weight_from_population(
                    self.weights, population[k]
                )
                rewards[k] = self.reward_function(weights_population)
            rewards = (rewards - np.mean(rewards)) / (np.std(rewards) + 1e-7)
            for index, w in enumerate(self.weights):
                A = np.array([p[index] for p in population])
                self.weights[index] = (
                    w
                    + self.learning_rate
                    / (self.population_size * self.sigma)
                    * np.dot(A.T, rewards).T
                )
            if (i + 1) % print_every == 0:
                print(
                    'iter %d. reward: %f'
                    % (i + 1, self.reward_function(self.weights))
                )
        print('time taken to train:', time.time() - lasttime, 'seconds')


class Model:
    def __init__(self, input_size, layer_size, output_size):
        self.weights = [
            np.random.randn(input_size, layer_size),
            np.random.randn(layer_size, output_size),
            np.random.randn(1, layer_size),
        ]

    def predict(self, inputs):
        feed = np.dot(inputs, self.weights[0]) + self.weights[-1]
        decision = np.dot(feed, self.weights[1])
        return decision

    def get_weights(self):
        return self.weights

    def set_weights(self, weights):
        self.weights = weights

# %%
class Agent:

    POPULATION_SIZE = 15
    SIGMA = 0.1
    LEARNING_RATE = 0.03

    def __init__(self, model, window_size, trend, skip, initial_money):
        self.model = model
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.initial_money = initial_money
        self.es = Deep_Evolution_Strategy(
            self.model.get_weights(),
            self.get_reward,
            self.POPULATION_SIZE,
            self.SIGMA,
            self.LEARNING_RATE,
        )

    def act(self, sequence):
        decision = self.model.predict(np.array(sequence))
        return np.argmax(decision[0])
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def get_reward(self, weights):
        initial_money = self.initial_money
        starting_money = initial_money
        self.model.weights = weights
        state = self.get_state(0)
        inventory = []
        quantity = 0
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])
                starting_money -= close[t]
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                starting_money += self.trend[t]

            state = next_state
        return ((starting_money - initial_money) / initial_money) * 100

    def fit(self, iterations, checkpoint):
        self.es.train(iterations, print_every = checkpoint)

    def buy(self):
        initial_money = self.initial_money
        state = self.get_state(0)
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t]:
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            state = next_state

        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest

# %%
close = df.Close.values.tolist()
window_size = 30
skip = 1
initial_money = 10000

model = Model(input_size = window_size, layer_size = 500, output_size = 3)
agent = Agent(model = model, 
              window_size = window_size,
              trend = close,
              skip = skip,
              initial_money = initial_money)
agent.fit(iterations = 500, checkpoint = 10)
# Out:
# iter 10. reward: 41.058799
# iter 20. reward: 40.113655
# iter 30. reward: 66.639198
# iter 40. reward: 69.350748
# iter 50. reward: 68.429850
# iter 60. reward: 72.015697
# iter 70. reward: 74.575449
# iter 80. reward: 75.066849
# iter 90. reward: 81.574751
# iter 100. reward: 85.637747
# iter 110. reward: 84.307648
# iter 120. reward: 83.104850
# iter 130. reward: 82.898898
# iter 140. reward: 83.887948
# iter 150. reward: 84.920249
# iter 160. reward: 84.872647
# iter 170. reward: 85.025450
# iter 180. reward: 81.098555
# iter 190. reward: 84.458251
# iter 200. reward: 87.698551
# iter 210. reward: 86.102750
# iter 220. reward: 89.542250
# iter 230. reward: 87.817848
# iter 240. reward: 88.299552
# iter 250. reward: 87.168251
# iter 260. reward: 87.678453
# iter 270. reward: 87.264653
# iter 280. reward: 90.029351
# iter 290. reward: 85.082853
# iter 300. reward: 86.606353
# iter 310. reward: 84.548750
# iter 320. reward: 91.348147
# iter 330. reward: 90.985200
# iter 340. reward: 89.999050
# iter 350. reward: 90.511449
# iter 360. reward: 92.075651
# iter 370. reward: 91.608851
# iter 380. reward: 91.900852
# iter 390. reward: 94.474950
# iter 400. reward: 70.842850
# iter 410. reward: 90.708348
# iter 420. reward: 94.196353
# iter 430. reward: 95.432750
# iter 440. reward: 95.294252
# iter 450. reward: 96.055452
# iter 460. reward: 95.720552
# iter 470. reward: 95.656552
# iter 480. reward: 94.807455
# iter 490. reward: 94.538752
# iter 500. reward: 95.613951
# time taken to train: 229.51715850830078 seconds

# %%
states_buy, states_sell, total_gains, invest = agent.buy()
# Out:
# day 4: buy 1 unit at price 1388.369995, total balance 8611.630005
# day 5, sell 1 unit at price 1403.260010, investment 1.072482 %, total balance 10014.890015,
# day 7: buy 1 unit at price 1349.329956, total balance 8665.560059
# day 8: buy 1 unit at price 1356.130005, total balance 7309.430054
# day 11: buy 1 unit at price 1373.484985, total balance 5935.945069
# day 12, sell 1 unit at price 1406.719971, investment 4.253223 %, total balance 7342.665040,
# day 13, sell 1 unit at price 1402.800049, investment 3.441414 %, total balance 8745.465089,
# day 14, sell 1 unit at price 1410.420044, investment 2.689149 %, total balance 10155.885133,
# day 15: buy 1 unit at price 1417.020020, total balance 8738.865113
# day 18: buy 1 unit at price 1428.920044, total balance 7309.945069
# day 19: buy 1 unit at price 1431.819946, total balance 5878.125123
# day 20, sell 1 unit at price 1439.219971, investment 1.566665 %, total balance 7317.345094,
# day 21: buy 1 unit at price 1436.380005, total balance 5880.965089
# day 22: buy 1 unit at price 1412.180054, total balance 4468.785035
# day 23, sell 1 unit at price 1438.390015, investment 0.662736 %, total balance 5907.175050,
# day 26, sell 1 unit at price 1465.849976, investment 2.376698 %, total balance 7373.025026,
# day 27: buy 1 unit at price 1403.839966, total balance 5969.185060
# day 28, sell 1 unit at price 1413.180054, investment -1.615168 %, total balance 7382.365114,
# day 29: buy 1 unit at price 1419.849976, total balance 5962.515138
# day 30: buy 1 unit at price 1442.719971, total balance 4519.795167
# day 32: buy 1 unit at price 1435.959961, total balance 3083.835206
# day 33, sell 1 unit at price 1431.719971, investment 1.383670 %, total balance 4515.555177,
# day 34: buy 1 unit at price 1451.859985, total balance 3063.695192
# day 35, sell 1 unit at price 1464.410034, investment 4.314599 %, total balance 4528.105226,
# day 36: buy 1 unit at price 1431.969971, total balance 3096.135255
# day 38: buy 1 unit at price 1359.900024, total balance 1736.235231
# day 39: buy 1 unit at price 1394.969971, total balance 341.265260
# day 42, sell 1 unit at price 1464.699951, investment 3.158783 %, total balance 1805.965211,
# day 43: buy 1 unit at price 1495.699951, total balance 310.265260
# day 44, sell 1 unit at price 1485.180054, investment 2.943058 %, total balance 1795.445314,
# day 45: buy 1 unit at price 1496.000000, total balance 299.445314
# day 54, sell 1 unit at price 1558.420044, investment 8.528099 %, total balance 1857.865358,
# day 55, sell 1 unit at price 1568.489990, investment 8.033144 %, total balance 3426.355348,
# day 56, sell 1 unit at price 1515.680054, investment 5.845799 %, total balance 4942.035402,
# day 57: buy 1 unit at price 1511.869995, total balance 3430.165407
# day 58, sell 1 unit at price 1530.199951, investment 12.522974 %, total balance 4960.365358,
# day 60, sell 1 unit at price 1522.020020, investment 9.107726 %, total balance 6482.385378,
# day 61: buy 1 unit at price 1531.449951, total balance 4950.935427
# day 63: buy 1 unit at price 1474.449951, total balance 3476.485476
# day 64: buy 1 unit at price 1464.969971, total balance 2011.515505
# day 66, sell 1 unit at price 1500.099976, investment 0.294178 %, total balance 3511.615481,
# day 68: buy 1 unit at price 1496.099976, total balance 2015.515505
# day 69: buy 1 unit at price 1480.319946, total balance 535.195559
# day 78, sell 1 unit at price 1588.199951, investment 6.163098 %, total balance 2123.395510,
# day 79, sell 1 unit at price 1608.219971, investment 6.372901 %, total balance 3731.615481,
# day 81, sell 1 unit at price 1634.329956, investment 6.717817 %, total balance 5365.945437,
# day 83, sell 1 unit at price 1634.180054, investment 10.833199 %, total balance 7000.125491,
# day 84, sell 1 unit at price 1660.709961, investment 13.361365 %, total balance 8660.835452,
# day 85, sell 1 unit at price 1728.280029, investment 15.519020 %, total balance 10389.115481,
# day 87, sell 1 unit at price 1591.040039, investment 7.479470 %, total balance 11980.155520,
# day 95: buy 1 unit at price 1495.530029, total balance 10484.625491
# day 96: buy 1 unit at price 1459.989990, total balance 9024.635501
# day 99: buy 1 unit at price 1415.209961, total balance 7609.425540
# day 100: buy 1 unit at price 1428.290039, total balance 6181.135501
# day 101: buy 1 unit at price 1444.959961, total balance 4736.175540
# day 102: buy 1 unit at price 1464.520020, total balance 3271.655520
# day 103, sell 1 unit at price 1469.329956, investment -1.751892 %, total balance 4740.985476,
# day 104: buy 1 unit at price 1469.599976, total balance 3271.385500
# day 105: buy 1 unit at price 1490.089966, total balance 1781.295534
# day 106: buy 1 unit at price 1458.420044, total balance 322.875490
# day 116, sell 1 unit at price 1573.010010, investment 7.741150 %, total balance 1895.885500,
# day 118: buy 1 unit at price 1555.930054, total balance 339.955446
# day 121, sell 1 unit at price 1641.000000, investment 15.954526 %, total balance 1980.955446,
# day 122: buy 1 unit at price 1590.449951, total balance 390.505495
# day 128, sell 1 unit at price 1650.209961, investment 15.537455 %, total balance 2040.715456,
# day 129: buy 1 unit at price 1749.130005, total balance 291.585451
# day 130, sell 1 unit at price 1763.369995, investment 22.035907 %, total balance 2054.955446,
# day 131, sell 1 unit at price 1761.750000, investment 20.295385 %, total balance 3816.705446,
# day 132: buy 1 unit at price 1763.000000, total balance 2053.705446
# day 135: buy 1 unit at price 1749.839966, total balance 303.865480
# day 137, sell 1 unit at price 1781.380005, investment 21.215299 %, total balance 2085.245485,
# day 138, sell 1 unit at price 1770.150024, investment 18.794842 %, total balance 3855.395509,
# day 139: buy 1 unit at price 1746.780029, total balance 2108.615480
# day 140, sell 1 unit at price 1763.920044, investment 20.947326 %, total balance 3872.535524,
# day 141, sell 1 unit at price 1742.189941, investment 11.970968 %, total balance 5614.725465,
# day 143, sell 1 unit at price 1768.880005, investment 11.218841 %, total balance 7383.605470,
# day 144, sell 1 unit at price 1771.430054, investment 1.274922 %, total balance 9155.035524,
# day 145, sell 1 unit at price 1793.189941, investment 1.712419 %, total balance 10948.225465,
# day 146: buy 1 unit at price 1760.739990, total balance 9187.485475
# day 147: buy 1 unit at price 1798.099976, total balance 7389.385499
# day 149, sell 1 unit at price 1826.770020, investment 4.396405 %, total balance 9216.155519,
# day 150, sell 1 unit at price 1827.989990, investment 4.649124 %, total balance 11044.145509,
# day 152, sell 1 unit at price 1818.550049, investment 3.283282 %, total balance 12862.695558,
# day 153, sell 1 unit at price 1784.130005, investment -0.776930 %, total balance 14646.825563,
# day 154: buy 1 unit at price 1775.329956, total balance 12871.495607
# day 155: buy 1 unit at price 1781.770020, total balance 11089.725587
# day 157, sell 1 unit at price 1767.770020, investment -0.425833 %, total balance 12857.495607,
# day 158: buy 1 unit at price 1763.000000, total balance 11094.495607
# day 160, sell 1 unit at price 1731.010010, investment -2.848853 %, total balance 12825.505617,
# day 161: buy 1 unit at price 1739.369995, total balance 11086.135622
# day 163: buy 1 unit at price 1732.380005, total balance 9353.755617
# day 164: buy 1 unit at price 1738.849976, total balance 7614.905641
# day 165: buy 1 unit at price 1776.089966, total balance 5838.815675
# day 166, sell 1 unit at price 1758.719971, investment -0.242770 %, total balance 7597.535646,
# day 167: buy 1 unit at price 1739.520020, total balance 5858.015626
# day 168: buy 1 unit at price 1751.880005, total balance 4106.135621
# day 169: buy 1 unit at price 1728.239990, total balance 2377.895631
# day 171: buy 1 unit at price 1735.290039, total balance 642.605592
# day 173, sell 1 unit at price 1807.209961, investment 3.900261 %, total balance 2449.815553,
# day 174: buy 1 unit at price 1766.719971, total balance 683.095582
# day 181, sell 1 unit at price 1891.250000, investment 9.170620 %, total balance 2574.345582,
# day 182, sell 1 unit at price 1901.050049, investment 9.328008 %, total balance 4475.395631,
# day 183: buy 1 unit at price 1899.400024, total balance 2575.995607
# day 186: buy 1 unit at price 1863.109985, total balance 712.885622
# day 189, sell 1 unit at price 1927.510010, investment 8.525472 %, total balance 2640.395632,
# day 190: buy 1 unit at price 2070.070068, total balance 570.325564
# day 191, sell 1 unit at price 2062.370117, investment 18.559723 %, total balance 2632.695681,
# day 192, sell 1 unit at price 2098.000000, investment 19.757061 %, total balance 4730.695681,
# day 193, sell 1 unit at price 2092.909912, investment 21.100653 %, total balance 6823.605593,
# day 194: buy 1 unit at price 2083.510010, total balance 4740.095583
# day 195, sell 1 unit at price 2095.379883, investment 20.750989 %, total balance 6835.475466,
# day 196: buy 1 unit at price 2095.889893, total balance 4739.585573
# day 197, sell 1 unit at price 2104.110107, investment 19.096979 %, total balance 6843.695680,
# day 198, sell 1 unit at price 2121.899902, investment 11.714219 %, total balance 8965.595582,
# day 199, sell 1 unit at price 2128.310059, investment 14.234268 %, total balance 11093.905641,
# day 200, sell 1 unit at price 2117.199951, investment 2.276729 %, total balance 13211.105592,
# day 201, sell 1 unit at price 2101.139893, investment 0.846163 %, total balance 15312.245485,
# day 203, sell 1 unit at price 2070.860107, investment -1.194232 %, total balance 17383.105592,
# day 206: buy 1 unit at price 2036.859985, total balance 15346.245607
# day 207: buy 1 unit at price 2081.510010, total balance 13264.735597
# day 208: buy 1 unit at price 2075.840088, total balance 11188.895509
# day 209: buy 1 unit at price 2026.709961, total balance 9162.185548
# day 210: buy 1 unit at price 2049.090088, total balance 7113.095460
# day 213: buy 1 unit at price 2052.699951, total balance 5060.395509
# day 214: buy 1 unit at price 2055.030029, total balance 3005.365480
# day 215, sell 1 unit at price 2114.770020, investment 3.825007 %, total balance 5120.135500,
# day 216: buy 1 unit at price 2061.919922, total balance 3058.215578
# day 217: buy 1 unit at price 2066.489990, total balance 991.725588
# day 222, sell 1 unit at price 2038.589966, investment -2.061967 %, total balance 3030.315554,
# day 224: buy 1 unit at price 2045.060059, total balance 985.255495
# day 232, sell 1 unit at price 2224.750000, investment 7.173477 %, total balance 3210.005495,
# day 233: buy 1 unit at price 2249.679932, total balance 960.325563
# day 236, sell 1 unit at price 2254.790039, investment 11.253711 %, total balance 3215.115602,
# day 237: buy 1 unit at price 2267.270020, total balance 947.845582
# day 240, sell 1 unit at price 2297.760010, investment 12.135627 %, total balance 3245.605592,
# day 241, sell 1 unit at price 2302.399902, investment 12.164464 %, total balance 5548.005494,
# day 242, sell 1 unit at price 2293.629883, investment 11.610529 %, total balance 7841.635377,
# day 244, sell 1 unit at price 2267.919922, investment 9.990689 %, total balance 10109.555299,
# day 245, sell 1 unit at price 2315.300049, investment 12.040226 %, total balance 12424.855348,
# day 246, sell 1 unit at price 2326.739990, investment 13.773675 %, total balance 14751.595338,
# day 248, sell 1 unit at price 2379.909912, investment 5.788823 %, total balance 17131.505250,
# day 249, sell 1 unit at price 2429.889893, investment 7.172497 %, total balance 19561.395143,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
